# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Display plots in notebook
# %matplotlib inline

# Set plot style
sns.set_style("whitegrid")
plt.rcParams['figure.figsize'] = (12, 6)

print("✅ Libraries imported successfully!")
# Out:
# Matplotlib is building the font cache; this may take a moment.
# ✅ Libraries imported successfully!

# %%
# Cell 2: Load the generated data
attractions = pd.read_csv('../data/processed/attractions.csv')
ratings = pd.read_csv('../data/processed/user_ratings.csv')
users = pd.read_csv('../data/processed/users.csv')

print("📊 Dataset Shapes:")
print(f"Attractions: {attractions.shape}")
print(f"Ratings: {ratings.shape}")
print(f"Users: {users.shape}")
# Out:
# 📊 Dataset Shapes:
# Attractions: (49, 12)
# Ratings: (2761, 4)
# Users: (200, 7)

# %%
# Cell 3: Display first few attractions
print("🏔️ Sample Attractions:\n")
attractions.head(10)
# Out:
# 🏔️ Sample Attractions:
#    attraction_id                           name           category  \
# 0              0   Mount Everest Base Camp Trek           Trekking
# 1              1              Annapurna Circuit           Trekking
# 2              2                  Langtang Trek           Trekking
# 3              3                Manaslu Circuit           Trekking
# 4              4             Upper Mustang Trek           Trekking
# 5              5               Gokyo Lakes Trek           Trekking
# 6              6        Kathmandu Durbar Square  Cultural Heritage
# 7              7            Patan Durbar Square  Cultural Heritage
# 8              8        Bhaktapur Durbar Square  Cultural Heritage
# 9              9  Swayambhunath (Monkey Temple)     Religious Site
#
#              region  rating  num_reviews  avg_cost_usd  duration_days  \
# 0    Everest Region     3.4           73          1360           10.0
# ...
